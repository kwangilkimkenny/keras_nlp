# %%
def read_file(novel):
    with open(novel) as f:
        str_text = f.read()
        
    return str_text

# %%
#read_file('novel')

# %%
import spacy

# %%
nlp = spacy.load('en',disable=['parser','tagger', 'ner'])

# %%
nlp.max_length = 1198623

# %%
def separate_punc(doc_text):
    return [token.text.lower() for token in nlp(doc_text) if token.text not in '!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n']

# %%
d = read_file('novel')

# %%
tokens = separate_punc(d)

# %%
tokens
# Out:
# ['project',
#  'gutenberg',
#  "'s",
#  'two',
#  'war',
#  'years',
#  'in',
#  'constantinople',
#  'by',
#  'harry',
#  'stuermer',
#  '\n\n',
#  'this',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'united',
#  'states',
#  'and',
#  'most',
#  'other',
#  'parts',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  ' ',
#  'you',
#  'may',
#  'copy',
#  'it',
#  'give',
#  'it',
#  'away',
#  'or',
#  're',
#  'use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'license',
#  'included',
#  'with',
#  'this',
#  'ebook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.org',
#  ' ',
#  'if',
#  'you',
#  'are',
#  'not',
#  'located',
#  'in',
#  'the',
#  'united',
#  'states',
#  'you',
#  "'ll",
#  'have',
#  'to',
#  'check',
#  'the',
#  'laws',
#  'of',
#  'the',
#  'country',
#  'where',
#  'you',
#  'are',
#  'located',
#  'before',
#  'using',
#  'this',
#  'ebook',
#  '\n\n\n\n',
#  'title',
#  'two',
#  'war',
#  'years',
#  'in',
#  'constantinople',
#  '\n       ',
#  'sketches',
#  'of',
#  'german',
#  'and',
#  'young',
#  'turkish',
#  'ethics',
#  'and',
#  'politics',
#  '\n\n',
#  'author',
#  'harry',
#  'stuermer',
#  '\n\n',
#  'translator',
#  'e.',
#  'allen',
#  '\n\n',
#  'release',
#  'date',
#  'november',
#  '6',
#  '2019',
#  'ebook',
#  '60638',
#  '\n\n',
#  'language',
#  'english',
#  '\n\n',
#  'character',
#  'set',
#  'encoding',
#  'iso-8859',
#  '1',
#  '\n\n',
#  'start',
#  'of',
#  'this',
#  'project',
#  'gutenberg',
#  'ebook',
#  'two',
#  'war',
#  'years',
#  'in',
#  'constantinople',
#  '\n\n\n\n\n',
#  'produced',
#  'by',
#  'graeme',
#  'mackreth',
#  'and',
#  'the',
#  'online',
#  'distributed',
#  'proofreading',
#  'team',
#  'at',
#  'http://www.pgdp.net',
#  'this',
#  'file',
#  'was',
#  'produced',
#  'from',
#  'images',
#  'generously',
#  'made',
#  'available',
#  'by',
#  'the',
#  'internet',
#  'archive',
#  '\n\n\n\n\n\n\n\n\n\n\n ',
#  'two',
#  'war',
#  'years',
#  'in',
#  '\n ',
#  'constantinople',
#  '\n\n\n\n\n ',
#  'two',
#  'war',
#  'years',
#  '\n ',
#  'in',
#  '\n ',
#  'constantinople',
#  '\n\n ',
#  'sketches',
#  'of',
#  'german',
#  'and',
#  'young',
#  'turkish',
#  '\n ',
#  'ethics',
#  'and',
#  'politics',
#  '\n\n\n ',
#  'by',
#  '\n ',
#  'dr',
#  'harry',
#  'stuermer',
#  '\n ',
#  'late',
#  'correspondent',
#  'of',
#  'the',
#  'kölnische',
#  'zeitung',
#  '\n ',
#  'in',
#  'constantinople',
#  '1915',
#  '16',
#  '\n\n\n ',
#  'translated',
#  'from',
#  'the',
#  'german',
#  '\n ',
#  'e.',
#  'allen',
#  '\n ',
#  'and',
#  'the',
#  'author',
#  '\n\n\n ',
#  'illustration',
#  '\n\n\n ',
#  'new',
#  'york',
#  '\n ',
#  'george',
#  'h.',
#  'doran',
#  'company',
#  '\n\n\n\n\n ',
#  'copyright',
#  '1917',
#  'by',
#  '\n ',
#  'george',
#  'h.',
#  'doran',
#  'company',
#  '\n\n\n ',
#  'printed',
#  'in',
#  'the',
#  'united',
#  'states',
#  'of',
#  'america',
#  '\n\n\n\n\n',
#  'declaration',
#  '\n\n\n',
#  'the',
#  'undersigned',
#  'hereby',
#  'declares',
#  'on',
#  'his',
#  'sworn',
#  'word',
#  'of',
#  'honour',
#  'that',
#  'in',
#  'writing',
#  'this',
#  'volume',
#  'he',
#  'has',
#  'been',
#  'in',
#  'no',
#  'way',
#  'inspired',
#  'by',
#  'outside',
#  'influence',
#  'and',
#  'that',
#  'he',
#  'has',
#  'never',
#  'had',
#  'any',
#  'dealings',
#  'whatsoever',
#  'material',
#  'or',
#  'otherwise',
#  'either',
#  'before',
#  'or',
#  'during',
#  'the',
#  'war',
#  'with',
#  'any',
#  'government',
#  'organisation',
#  'propaganda',
#  'or',
#  'personality',
#  'hostile',
#  'to',
#  'germany',
#  'or',
#  'turkey',
#  'or',
#  'even',
#  'of',
#  'a',
#  'neutral',
#  'character',
#  'his',
#  'conscience',
#  'alone',
#  'has',
#  'urged',
#  'him',
#  'to',
#  'write',
#  'and',
#  'publish',
#  'his',
#  'impressions',
#  'and',
#  'he',
#  'hopes',
#  'that',
#  'by',
#  'so',
#  'doing',
#  'he',
#  'may',
#  'perform',
#  'a',
#  'service',
#  'towards',
#  'the',
#  'cause',
#  'of',
#  'truth',
#  'and',
#  'civilisation',
#  '\n\n',
#  'moreover',
#  'he',
#  'can',
#  'give',
#  'formal',
#  'assurance',
#  'that',
#  'he',
#  'has',
#  'expressly',
#  'avoided',
#  'making',
#  'the',
#  'acquaintance',
#  'of',
#  'any',
#  'person',
#  'resident',
#  'in',
#  'switzerland',
#  'until',
#  'his',
#  'manuscript',
#  'should',
#  'have',
#  'been',
#  'sent',
#  'to',
#  'press',
#  '\n\n',
#  'furthermore',
#  'he',
#  'has',
#  'been',
#  'actuated',
#  'by',
#  'no',
#  'personal',
#  'motives',
#  'in',
#  'thus',
#  'giving',
#  'public',
#  'expression',
#  'to',
#  'his',
#  'experiences',
#  'and',
#  'opinions',
#  'for',
#  'he',
#  'has',
#  'no',
#  'personal',
#  'grievance',
#  'either',
#  'material',
#  'or',
#  'moral',
#  'against',
#  'any',
#  'person',
#  'whatsoever',
#  '\n\n\n',
#  'illustration',
#  'dr.',
#  'h.',
#  'stuermer',
#  '\n\n ',
#  'geneva',
#  '\n ',
#  'june',
#  '1917_.',
#  '\n\n\n\n\n',
#  'preface',
#  '\n\n\n',
#  'while',
#  'the',
#  'author',
#  'of',
#  'this',
#  'work',
#  'was',
#  'waiting',
#  'on',
#  'the',
#  'frontier',
#  'of',
#  'switzerland',
#  'for',
#  'final',
#  'permission',
#  'from',
#  'the',
#  'german',
#  'authorities',
#  'to',
#  'enter',
#  'that',
#  'country',
#  'germany',
#  'committed',
#  'her',
#  'second',
#  'great',
#  'crime',
#  'her',
#  'first',
#  'having',
#  'completely',
#  'missed',
#  'its',
#  'mark',
#  'she',
#  'had',
#  'begun',
#  'to',
#  'realise',
#  'that',
#  'she',
#  'was',
#  'beaten',
#  'in',
#  'the',
#  'great',
#  'conflict',
#  'which',
#  'she',
#  'had',
#  'so',
#  'wantonly',
#  'provoked',
#  'with',
#  'that',
#  'characteristic',
#  'over',
#  'confidence',
#  'in',
#  'the',
#  'power',
#  'of',
#  'her',
#  'own',
#  'militarism',
#  'and',
#  'disdainful',
#  'undervaluation',
#  'of',
#  'the',
#  'morale',
#  'and',
#  'general',
#  'capacities',
#  'of',
#  'her',
#  'enemies',
#  'in',
#  'final',
#  'renunciation',
#  'of',
#  'any',
#  'last',
#  'remnants',
#  'of',
#  'humanity',
#  'in',
#  'her',
#  'methods',
#  'she',
#  'was',
#  'now',
#  'making',
#  'a',
#  'dying',
#  'effort',
#  'to',
#  'help',
#  'her',
#  'already',
#  'lost',
#  'cause',
#  'by',
#  'a',
#  'ruthless',
#  'extension',
#  'of',
#  'her',
#  'policy',
#  'of',
#  'piracy',
#  'at',
#  'sea',
#  'and',
#  'a',
#  'gratification',
#  'of',
#  'all',
#  'her',
#  'brutal',
#  'instincts',
#  'in',
#  'complete',
#  'violation',
#  'of',
#  'the',
#  'rights',
#  'of',
#  'neutral',
#  'countries',
#  '\n\n',
#  'it',
#  'is',
#  'therefore',
#  'with',
#  'all',
#  'the',
#  'more',
#  'inward',
#  'conviction',
#  'with',
#  'all',
#  'the',
#  'more',
#  'urgent',
#  'moral',
#  'persuasion',
#  'that',
#  'the',
#  'author',
#  'makes',
#  'use',
#  'of',
#  'the',
#  'rare',
#  'opportunity',
#  'offered',
#  'him',
#  'by',
#  'residence',
#  'in',
#  'switzerland',
#  'to',
#  'range',
#  'himself',
#  'boldly',
#  'on',
#  'the',
#  'side',
#  'of',
#  'truth',
#  'and',
#  'show',
#  'that',
#  'there',
#  'are',
#  'still',
#  'germans',
#  'who',
#  'find',
#  'it',
#  'impossible',
#  'to',
#  'condone',
#  'even',
#  'tacitly',
#  'the',
#  'moral',
#  'transgression',
#  'and',
#  'political',
#  'stupidity',
#  'of',
#  'their',
#  'own',
#  'and',
#  'an',
#  'allied',
#  'government',
#  'that',
#  'is',
#  'the',
#  'sole',
#  'purpose',
#  'of',
#  'this',
#  'publication',
#  '\n\n',
#  'regardless',
#  'of',
#  'the',
#  'consequences',
#  'he',
#  'holds',
#  'it',
#  'to',
#  'be',
#  'his',
#  'duty',
#  'and',
#  'his',
#  'privilege',
#  'just',
#  'because',
#  'he',
#  'is',
#  'a',
#  'german',
#  'to',
#  'make',
#  'a',
#  'frank',
#  'statement',
#  'from',
#  'the',
#  'point',
#  'of',
#  'view',
#  'of',
#  'human',
#  'civilisation',
#  'of',
#  'what',
#  'have',
#  'become',
#  'his',
#  'convictions',
#  'from',
#  'personal',
#  'observations',
#  'made',
#  'in',
#  'the',
#  'course',
#  'of',
#  'six',
#  'months',
#  'of',
#  'actual',
#  'warfare',
#  'and',
#  'practically',
#  'two',
#  'years',
#  'of',
#  'subsequent',
#  'journalistic',
#  'activity',
#  'he',
#  'spent',
#  'the',
#  'time',
#  'from',
#  'spring',
#  '1915',
#  'to',
#  'christmas',
#  '1916',
#  'in',
#  'turkey',
#  'and',
#  'will',
#  'of',
#  'course',
#  'only',
#  'deal',
#  'with',
#  'what',
#  'he',
#  'knows',
#  'from',
#  'personal',
#  'observation',
#  'the',
#  'following',
#  'essays',
#  'are',
#  'of',
#  'the',
#  'nature',
#  'merely',
#  'of',
#  'sketches',
#  'and',
#  'make',
#  'no',
#  'claim',
#  'whatever',
#  'to',
#  'completeness',
#  '\n\n',
#  'with',
#  'regard',
#  'to',
#  'purely',
#  'german',
#  'politics',
#  'and',
#  'ethics',
#  'therefore',
#  'the',
#  'author',
#  'will',
#  'confine',
#  'himself',
#  'to',
#  'a',
#  'few',
#  'indications',
#  'and',
#  'impressions',
#  'of',
#  'a',
#  'personal',
#  'kind',
#  'but',
#  'he',
#  'can',
#  'not',
#  'forget',
#  'the',
#  'rôle',
#  'germany',
#  'has',
#  'played',
#  'in',
#  'turkey',
#  'as',
#  'an',
#  'ally',
#  'of',
#  'the',
#  'present',
#  'young',
#  'turkish',
#  'government',
#  'nor',
#  'can',
#  'he',
#  'ignore',
#  'germany',
#  "'s",
#  'responsibility',
#  'for',
#  'the',
#  'atrocities',
#  'committed',
#  'by',
#  'them',
#  'the',
#  'author',
#  'publishes',
#  'his',
#  'impressions',
#  'with',
#  'a',
#  'perfectly',
#  'clear',
#  'conscience',
#  'secure',
#  'in',
#  'the',
#  'conviction',
#  'that',
#  'as',
#  'the',
#  'representative',
#  'of',
#  'a',
#  'german',
#  'paper',
#  'he',
#  'never',
#  'once',
#  'wrote',
#  'a',
#  'single',
#  'word',
#  'in',
#  'favour',
#  'of',
#  'this',
#  'criminal',
#  'war',
#  'and',
#  'that',
#  'during',
#  'his',
#  'stay',
#  'of',
#  'more',
#  'than',
#  'twenty',
#  'months',
#  'in',
#  'turkey',
#  'he',
#  'never',
#  'concealed',
#  'his',
#  'true',
#  'opinions',
#  'as',
#  'soon',
#  'as',
#  'he',
#  'had',
#  'definitely',
#  'made',
#  'up',
#  'his',
#  'mind',
#  'what',
#  'these',
#  'were',
#  '\n\n',
#  'on',
#  'the',
#  'contrary',
#  'he',
#  'was',
#  'rather',
#  'dangerously',
#  'candid',
#  'and',
#  'frank',
#  'in',
#  'speaking',
#  'to',
#  'anyone',
#  'who',
#  'wanted',
#  'to',
#  'listen',
#  'to',
#  'him',
#  '--',
#  'so',
#  'much',
#  'so',
#  'that',
#  'it',
#  'is',
#  'almost',
#  'a',
#  'miracle',
#  'that',
#  'he',
#  'ever',
#  'reached',
#  'a',
#  'neutral',
#  'country',
#  'after',
#  'the',
#  'war',
#  'he',
#  'will',
#  'be',
#  'in',
#  'a',
#  'position',
#  'to',
#  'appeal',
#  'to',
#  'the',
#  'testimony',
#  'of',
#  'dozens',
#  'of',
#  'people',
#  'of',
#  'high',
#  'standing',
#  'in',
#  'all',
#  'walks',
#  'of',
#  'life',
#  'that',
#  'in',
#  'both',
#  'thought',
#  'and',
#  'action',
#  'a',
#  'deep',
#  'cleft',
#  'has',
#  'always',
#  'divided',
#  'him',
#  'from',
#  'his',
#  'colleagues',
#  'and',
#  'that',
#  'he',
#  'has',
#  'ever',
#  'ardently',
#  'longed',
#  'for',
#  'the',
#  'moment',
#  'when',
#  'he',
#  'might',
#  'freely',
#  'and',
#  'without',
#  'fear',
#  'of',
#  'consequences',
#  'do',
#  'his',
#  'bit',
#  'towards',
#  'the',
#  'enlightenment',
#  'of',
#  'the',
#  'civilised',
#  'world',
#  '\n\n',
#  'may',
#  'these',
#  'lines',
#  'written',
#  'in',
#  'all',
#  'sincerity',
#  'and',
#  'hereby',
#  'submitted',
#  'to',
#  'the',
#  'tribunal',
#  'of',
#  'public',
#  'opinion',
#  'free',
#  'the',
#  'author',
#  'at',
#  ...]

# %%
len(tokens)
# Out:
# 57466

# %%
#25 >>> #26(network pridict)

# %%
train_len = 25 + 1

text_sequences = []

for i in range(train_len, len(tokens)):
    seq = tokens[i-train_len:i]
    
    text_sequences.append(seq)

# %%
type(text_sequences)
# Out:
# list

# %%
text_sequences[0]
# Out:
# ['project',
#  'gutenberg',
#  "'s",
#  'two',
#  'war',
#  'years',
#  'in',
#  'constantinople',
#  'by',
#  'harry',
#  'stuermer',
#  '\n\n',
#  'this',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'united',
#  'states',
#  'and']

# %%
text_sequences[1]
# Out:
# ['gutenberg',
#  "'s",
#  'two',
#  'war',
#  'years',
#  'in',
#  'constantinople',
#  'by',
#  'harry',
#  'stuermer',
#  '\n\n',
#  'this',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'united',
#  'states',
#  'and',
#  'most']

# %%
' '.join(text_sequences[0])
# Out:
# "project gutenberg 's two war years in constantinople by harry stuermer \n\n this ebook is for the use of anyone anywhere in the united states and"

# %%
' '.join(text_sequences[1])
# Out:
# "gutenberg 's two war years in constantinople by harry stuermer \n\n this ebook is for the use of anyone anywhere in the united states and most"

# %%
from keras.preprocessing.text import Tokenizer
# Out:
# Using TensorFlow backend.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_sequences)

# %%
sequences = tokenizer.texts_to_sequences(text_sequences)

# %%
sequences[0]
# Out:
# [81,
#  82,
#  41,
#  165,
#  33,
#  271,
#  5,
#  60,
#  19,
#  1832,
#  1477,
#  11,
#  16,
#  659,
#  17,
#  8,
#  1,
#  228,
#  2,
#  279,
#  2389,
#  5,
#  1,
#  426,
#  270,
#  3]

# %%
sequences[1]
# Out:
# [82,
#  41,
#  165,
#  33,
#  271,
#  5,
#  60,
#  19,
#  1832,
#  1477,
#  11,
#  16,
#  659,
#  17,
#  8,
#  1,
#  228,
#  2,
#  279,
#  2389,
#  5,
#  1,
#  426,
#  270,
#  3,
#  53]

# %%
for i in sequences[0]:
    print(f"{i} : {tokenizer.index_word[i]}")
    
#check words to tokens   

tokenizer.index_word
# Out:
# 81 : project
# 82 : gutenberg
# 41 : 's
# 165 : two
# 33 : war
# 271 : years
# 5 : in
# 60 : constantinople
# 19 : by
# 1832 : harry
# 1477 : stuermer
# 11 :
#
#
# 16 : this
# 659 : ebook
# 17 : is
# 8 : for
# 1 : the
# 228 : use
# 2 : of
# 279 : anyone
# 2389 : anywhere
# 5 : in
# 1 : the
# 426 : united
# 270 : states
# 3 : and
# {1: 'the',
#  2: 'of',
#  3: 'and',
#  4: 'to',
#  5: 'in',
#  6: 'a',
#  7: 'that',
#  8: 'for',
#  9: 'with',
#  10: 'was',
#  11: '\n\n',
#  12: 'as',
#  13: '--',
#  14: 'i',
#  15: 'on',
#  16: 'this',
#  17: 'is',
#  18: 'it',
#  19: 'by',
#  20: 'have',
#  21: 'had',
#  22: 'from',
#  23: 'not',
#  24: 'turkish',
#  25: 'german',
#  26: 'at',
#  27: 'their',
#  28: 'his',
#  29: 'be',
#  30: 'he',
#  31: 'turkey',
#  32: 'all',
#  33: 'war',
#  34: 'were',
#  35: 'they',
#  36: 'but',
#  37: 'who',
#  38: 'or',
#  39: 'one',
#  40: 'which',
#  41: "'s",
#  42: '\n  ',
#  43: 'so',
#  44: 'will',
#  45: 'would',
#  46: 'an',
#  47: 'been',
#  48: 'any',
#  49: 'even',
#  50: 'my',
#  51: 'has',
#  52: 'more',
#  53: 'most',
#  54: 'germany',
#  55: 'are',
#  56: 'turks',
#  57: 'no',
#  58: 'these',
#  59: 'only',
#  60: 'constantinople',
#  61: 'against',
#  62: 'there',
#  63: 'very',
#  64: 'people',
#  65: 'when',
#  66: 'government',
#  67: 'them',
#  68: 'we',
#  69: 'her',
#  70: 'if',
#  71: 'me',
#  72: 'about',
#  73: 'out',
#  74: 'time',
#  75: 'after',
#  76: 'you',
#  77: 'political',
#  78: 'can',
#  79: 'what',
#  80: 'up',
#  81: 'project',
#  82: 'gutenberg',
#  83: 'whole',
#  84: 'young',
#  85: 'than',
#  86: 'military',
#  87: 'its',
#  88: 'own',
#  89: 'into',
#  90: 'far',
#  91: 'other',
#  92: 'great',
#  93: 'much',
#  94: 'enver',
#  95: 'work',
#  96: 'could',
#  97: 'under',
#  98: 'him',
#  99: 'then',
#  100: 'well',
#  101: 'such',
#  102: 'made',
#  103: 'do',
#  104: 'way',
#  105: 'long',
#  106: 'now',
#  107: 'being',
#  108: 'armenian',
#  109: 'without',
#  110: 'still',
#  111: 'how',
#  112: 'russia',
#  113: 'over',
#  114: 'too',
#  115: 'committee',
#  116: 'may',
#  117: 'quite',
#  118: 'those',
#  119: 'before',
#  120: 'tm',
#  121: 'she',
#  122: 'through',
#  123: 'never',
#  124: 'part',
#  125: 'spite',
#  126: 'european',
#  127: 'our',
#  128: 'already',
#  129: 'official',
#  130: 'did',
#  131: 'case',
#  132: 'entente',
#  133: 'country',
#  134: 'where',
#  135: 'first',
#  136: 'ever',
#  137: 'like',
#  138: 'must',
#  139: 'many',
#  140: 'pasha',
#  141: 'men',
#  142: 'english',
#  143: 'should',
#  144: 'russian',
#  145: 'talaat',
#  146: 'embassy',
#  147: 'some',
#  148: 'day',
#  149: 'world',
#  150: 'anatolia',
#  151: 'nothing',
#  152: '1916',
#  153: 'life',
#  154: 'armenians',
#  155: 'race',
#  156: 'while',
#  157: 'paper',
#  158: 'system',
#  159: 'politics',
#  160: 'last',
#  161: 'course',
#  162: 'however',
#  163: 'might',
#  164: 'pan',
#  165: 'two',
#  166: 'towards',
#  167: 'man',
#  168: 'new',
#  169: 'himself',
#  170: 'french',
#  171: 'commercial',
#  172: 'every',
#  173: 'personal',
#  174: 'true',
#  175: 'pera',
#  176: 'off',
#  177: 'social',
#  178: 'fact',
#  179: 'once',
#  180: 'ottoman',
#  181: 'place',
#  182: 'again',
#  183: 'civilisation',
#  184: 'make',
#  185: 'few',
#  186: 'among',
#  187: 'between',
#  188: 'enough',
#  189: 'themselves',
#  190: 'works',
#  191: 'general',
#  192: 'policy',
#  193: 'present',
#  194: 'really',
#  195: 'europe',
#  196: 'side',
#  197: 'just',
#  198: 'point',
#  199: 'money',
#  200: 'old',
#  201: 'state',
#  202: 'same',
#  203: 'purely',
#  204: 'dardanelles',
#  205: 'population',
#  206: 'djemal',
#  207: 'perhaps',
#  208: 'means',
#  209: 'said',
#  210: 'give',
#  211: 'always',
#  212: 'little',
#  213: 'terrible',
#  214: 'full',
#  215: 'simply',
#  216: 'set',
#  217: 'view',
#  218: 'thousands',
#  219: 'empire',
#  220: 'peace',
#  221: 'modern',
#  222: 'although',
#  223: 'capital',
#  224: 'real',
#  225: 'beginning',
#  226: 'idea',
#  227: 'foundation',
#  228: 'use',
#  229: 'public',
#  230: 'lack',
#  231: 'holy',
#  232: 'greek',
#  233: 'arabian',
#  234: 'us',
#  235: 'land',
#  236: 'certainly',
#  237: 'found',
#  238: 'end',
#  239: 'get',
#  240: 'went',
#  241: 'opportunity',
#  242: 'efforts',
#  243: 'islam',
#  244: 'often',
#  245: 'rate',
#  246: 'take',
#  247: 'everything',
#  248: 'come',
#  249: 'cause',
#  250: 'kind',
#  251: 'position',
#  252: 'high',
#  253: 'thought',
#  254: 'hand',
#  255: 'given',
#  256: 'see',
#  257: 'right',
#  258: 'good',
#  259: 'propaganda',
#  260: 'find',
#  261: 'opinion',
#  262: 'england',
#  263: 'pro',
#  264: 'agreement',
#  265: 'say',
#  266: 'brought',
#  267: 'attempt',
#  268: 'finally',
#  269: 'electronic',
#  270: 'states',
#  271: 'years',
#  272: 'germans',
#  273: 'because',
#  274: 'practically',
#  275: 'intellectual',
#  276: 'possible',
#  277: 'powers',
#  278: 'question',
#  279: 'anyone',
#  280: 'authorities',
#  281: 'rather',
#  282: 'moment',
#  283: 'death',
#  284: 'victory',
#  285: 'interests',
#  286: "'",
#  287: 'complete',
#  288: 'civilised',
#  289: 'chapter',
#  290: 'gallipoli',
#  291: 'officers',
#  292: 'economic',
#  293: 'foreign',
#  294: 'law',
#  295: 'colonial',
#  296: 'later',
#  297: 'turk',
#  298: 'eyes',
#  299: 'terms',
#  300: 'character',
#  301: 'power',
#  302: 'methods',
#  303: 'free',
#  304: 'important',
#  305: 'yet',
#  306: 'best',
#  307: 'trade',
#  308: 'circles',
#  309: 'here',
#  310: 'spirit',
#  311: 'go',
#  312: 'saw',
#  313: 'front',
#  314: 'interior',
#  315: 'word',
#  316: 'further',
#  317: 'result',
#  318: '\n\n  ',
#  319: '"--',
#  320: 'central',
#  321: 'national',
#  322: 'greater',
#  323: 'syria',
#  324: 'certain',
#  325: 'down',
#  326: 'also',
#  327: 'came',
#  328: 'probably',
#  329: 'know',
#  330: 'things',
#  331: 'copyright',
#  332: 'either',
#  333: 'sea',
#  334: 'soon',
#  335: 'taken',
#  336: 'british',
#  337: 'troops',
#  338: 'persecutions',
#  339: 'attitude',
#  340: 'fall',
#  341: 'reform',
#  342: 'example',
#  343: 'days',
#  344: 'absolutely',
#  345: 'soldiers',
#  346: 'women',
#  347: 'information',
#  348: 'called',
#  349: 'during',
#  350: 'neutral',
#  351: 'opinions',
#  352: 'become',
#  353: 'entry',
#  354: 'bulgaria',
#  355: 'summer',
#  356: 'territory',
#  357: 'armenia',
#  358: 'let',
#  359: 'indeed',
#  360: 'believe',
#  361: 'stamboul',
#  362: 'order',
#  363: 'used',
#  364: 'anything',
#  365: 'known',
#  366: 'service',
#  367: 'final',
#  368: 'activity',
#  369: 'clear',
#  370: 'greeks',
#  371: 'abdul',
#  372: 'element',
#  373: 'ideas',
#  374: 'back',
#  375: 'left',
#  376: 'took',
#  377: 'longer',
#  378: 'non',
#  379: 'gave',
#  380: 'face',
#  381: 'going',
#  382: 'measures',
#  383: 'least',
#  384: 'help',
#  385: '1915',
#  386: 'having',
#  387: 'regard',
#  388: 'single',
#  389: 'number',
#  390: 'enemy',
#  391: 'hamid',
#  392: 'anti',
#  393: 'feelings',
#  394: 'subject',
#  395: 'knowledge',
#  396: 'less',
#  397: 'rule',
#  398: 'matter',
#  399: 'von',
#  400: 'knew',
#  401: 'put',
#  402: 'heard',
#  403: 'away',
#  404: 'influence',
#  405: 'moral',
#  406: 'lost',
#  407: 'therefore',
#  408: 'both',
#  409: 'offensive',
#  410: 'former',
#  411: 'prisoners',
#  412: 'turkification',
#  413: 'greece',
#  414: 'myself',
#  415: 'think',
#  416: 'form',
#  417: 'look',
#  418: 'army',
#  419: 'doubt',
#  420: 'able',
#  421: 'history',
#  422: 'hundreds',
#  423: 'different',
#  424: 'exactly',
#  425: 'within',
#  426: 'united',
#  427: '\n\n\n\n\n',
#  428: 'material',
#  429: 'truth',
#  430: 'press',
#  431: 'second',
#  432: 'brutal',
#  433: 'carried',
#  434: 'caucasus',
#  435: 'subjects',
#  436: 'fanaticism',
#  437: 'arabs',
#  438: 'feeling',
#  439: 'open',
#  440: 'treated',
#  441: 'another',
#  442: 'better',
#  443: 'wonderful',
#  444: 'done',
#  445: 'told',
#  446: 'jingoistic',
#  447: 'thing',
#  448: 'east',
#  449: 'entirely',
#  450: 'seen',
#  451: 'got',
#  452: 'post',
#  453: 'paid',
#  454: 'whose',
#  455: 'license',
#  456: '\n\n\n',
#  457: 'countries',
#  458: 'months',
#  459: 'written',
#  460: 'events',
#  461: 'anatolian',
#  462: 'turanism',
#  463: 'reforms',
#  464: 'western',
#  465: 'lands',
#  466: 'surely',
#  467: 'received',
#  468: 'thoroughly',
#  469: 'desire',
#  470: 'naturally',
#  471: 'hatred',
#  472: 'pay',
#  473: 'belonging',
#  474: 'suddenly',
#  475: 'existence',
#  476: 'railway',
#  477: 'sultan',
#  478: 'your',
#  479: 'office',
#  480: 'bread',
#  481: 'donations',
#  482: 'archive',
#  483: 'parts',
#  484: 'language',
#  485: 'available',
#  486: 'making',
#  487: 'sent',
#  488: 'completely',
#  489: 'whatever',
#  490: 'since',
#  491: 'international',
#  492: 'situation',
#  493: 'necessity',
#  494: 'articles',
#  495: 'value',
#  496: 'something',
#  497: 'members',
#  498: 'turned',
#  499: 'jingoism',
#  500: 'children',
#  501: 'progress',
#  502: 'inhabitants',
#  503: 'culture',
#  504: 'poor',
#  505: 'asia',
#  506: 'greatest',
#  507: 'enormous',
#  508: 'straits',
#  509: 'importance',
#  510: 'copy',
#  511: 'switzerland',
#  512: 'until',
#  513: 'crime',
#  514: 'knows',
#  515: 'representative',
#  516: 'control',
#  517: 'fate',
#  518: 'semi',
#  519: 'fine',
#  520: 'capitulations',
#  521: 'movement',
#  522: 'particularly',
#  523: 'highest',
#  524: 'needs',
#  525: 'considerable',
#  526: 'protection',
#  527: 'practical',
#  528: 'began',
#  529: 'necessary',
#  530: 'cases',
#  531: 'short',
#  532: 'return',
#  533: 'confidential',
#  534: 'tried',
#  535: 'remained',
#  536: 'daily',
#  537: 'mention',
#  538: 'sympathy',
#  539: 'prevent',
#  540: 'affairs',
#  541: 'hands',
#  542: 'till',
#  543: 'apart',
#  544: 'police',
#  545: 'large',
#  546: 'conclusion',
#  547: 'wife',
#  548: 'fully',
#  549: 'does',
#  550: 'connection',
#  551: 'gold',
#  552: 'access',
#  553: 'djihad',
#  554: 'literary',
#  555: 'laws',
#  556: '\n ',
#  557: 'committed',
#  558: 'show',
#  559: 'human',
#  560: 'perfectly',
#  561: 'wrote',
#  562: 'reached',
#  563: 'passed',
#  564: 'book',
#  565: 'baghdad',
#  566: 'politicians',
#  567: 'rumania',
#  568: 'clique',
#  569: 'islamism',
#  570: 'failure',
#  571: 'future',
#  572: 'peoples',
#  573: 'allowed',
#  574: 'speak',
#  575: 'am',
#  576: 'doubtful',
#  577: 'concerned',
#  578: 'minded',
#  579: 'others',
#  580: 'charge',
#  581: 'france',
#  582: 'direction',
#  583: 'house',
#  584: 'victims',
#  585: 'special',
#  586: 'scarcely',
#  587: 'journalist',
#  588: 'turn',
#  589: 'visit',
#  590: 'chief',
#  591: 'reports',
#  592: 'officials',
#  593: 'half',
#  594: 'districts',
#  595: 'taking',
#  596: 'accepted',
#  597: 'pure',
#  598: 'provide',
#  599: 'zekki',
#  600: 'trademark',
#  601: 'ethics',
#  602: 'correspondent',
#  603: 'alone',
#  604: 'thus',
#  605: 'militarism',
#  606: 'enemies',
#  607: 'humanity',
#  608: 'criminal',
#  609: 'deep',
#  610: 'fear',
#  611: 'effect',
#  612: 'campaign',
#  613: 'illusions',
#  614: 'el',
#  615: 'treatment',
#  616: 'hard',
#  617: 'results',
#  618: 'victorious',
#  619: 'dramatic',
#  620: 'forth',
#  621: 'grand',
#  622: 'highly',
#  623: 'lacking',
#  624: 'whether',
#  625: 'expansion',
#  626: 'felt',
#  627: 'active',
#  628: 'whom',
#  629: 'everyone',
#  630: 'agree',
#  631: 'union',
#  632: 'leave',
#  633: 'staff',
#  634: 'notice',
#  635: 'upon',
#  636: 'fight',
#  637: 'sympathies',
#  638: 'thousand',
#  639: 'keep',
#  640: 'bound',
#  641: 'mohammedan',
#  642: 'apparently',
#  643: 'streets',
#  644: 'hitherto',
#  645: 'together',
#  646: 'minister',
#  647: 'rid',
#  648: 'price',
#  649: 'need',
#  650: 'development',
#  651: 'arab',
#  652: 'west',
#  653: 'bey',
#  654: 'managed',
#  655: 'won',
#  656: 'egypt',
#  657: 'blood',
#  658: 'paragraph',
#  659: 'ebook',
#  660: 'zeitung',
#  661: 'honour',
#  662: 'organisation',
#  663: 'following',
#  664: 'ally',
#  665: 'mind',
#  666: 'early',
#  667: 'year',
#  668: '\n\n\n  ',
#  669: 'separate',
#  670: '?--',
#  671: 'foot',
#  672: 'living',
#  673: 'standpoint',
#  674: 'proper',
#  675: 'africa',
#  676: 'politically',
#  677: 'recognised',
#  678: 'convinced',
#  679: 'possibility',
#  680: 'freedom',
#  681: 'especially',
#  682: 'expected',
#  683: 'hold',
#  684: 'berlin',
#  685: 'lieutenant',
#  686: 'weeks',
#  687: 'kept',
#  688: 'families',
#  689: 'evident',
#  690: 'contrast',
#  691: 'series',
#  692: 'interest',
#  693: 'became',
#  694: 'throughout',
#  695: 'getting',
#  696: 'directly',
#  697: 'carrying',
#  698: 'purposes',
#  699: 'times',
#  700: 'food',
#  701: 'small',
#  702: 'internal',
#  703: 'censorship',
#  704: 'low',
#  705: 'ruling',
#  706: 'light',
#  707: 'win',
#  708: 'shall',
#  709: 'decided',
#  710: 'prince',
#  711: 'gain',
#  712: 'intrigues',
#  713: 'ground',
#  714: 'opposition',
#  715: 'including',
#  716: 'inner',
#  717: 'refund',
#  718: 'author',
#  719: 'kölnische',
#  720: 'otherwise',
#  721: 'conscience',
#  722: 'write',
#  723: 'impressions',
#  724: 'formal',
#  725: 'frontier',
#  726: 'permission',
#  727: 'ruthless',
#  728: 'rights',
#  729: 'offered',
#  730: 'consequences',
#  731: 'actual',
#  732: 'deal',
#  733: 'merely',
#  734: 'nor',
#  735: 'colleagues',
#  736: 'freely',
#  737: 'several',
#  738: 'outbreak',
#  739: 'king',
#  740: 'kut',
#  741: 'requisitioning',
#  742: 'unsuccessful',
#  743: 'representatives',
#  744: 'emancipation',
#  745: 'starvation',
#  746: 'herself',
#  747: 'hangman',
#  748: 'sentence',
#  749: 'colonies',
#  750: 'carry',
#  751: 'latter',
#  752: 'provided',
#  753: 'though',
#  754: 'feel',
#  755: 'officer',
#  756: 'superior',
#  757: 'instead',
#  758: 'narrow',
#  759: 'believed',
#  760: 'fell',
#  761: 'impression',
#  762: 'head',
#  763: 'lived',
#  764: 'millions',
#  765: 'unfortunately',
#  766: 'pass',
#  767: 'newspapers',
#  768: 'ruin',
#  769: 'report',
#  770: 'editorial',
#  771: 'informed',
#  772: 'absolute',
#  773: 'regarded',
#  774: 'régime',
#  775: 'read',
#  776: 'strong',
#  777: 'combined',
#  778: 'decision',
#  779: 'fanatical',
#  780: 'individual',
#  781: 'facts',
#  782: 'ill',
#  783: 'cold',
#  784: 'extermination',
#  785: 'recognise',
#  786: 'held',
#  787: 'flourishing',
#  788: 'financial',
#  789: 'near',
#  790: 'pounds',
#  791: 'city',
#  792: 'collapse',
#  793: 'ammunition',
#  794: 'looked',
#  795: 'successful',
#  796: 'mission',
#  797: 'black',
#  798: 'conditions',
#  799: 'labour',
#  800: 'comes',
#  801: 'hoped',
#  802: 'associated',
#  803: 'cost',
#  804: 'almost',
#  805: 'using',
#  806: 'produced',
#  807: 'distributed',
#  808: 'late',
#  809: 'company',
#  810: 'doing',
#  811: 'expression',
#  812: 'characteristic',
#  813: 'confidence',
#  814: 'conviction',
#  815: 'nature',
#  816: 'rôle',
#  817: 'wanted',
#  818: 'lines',
#  819: 'direct',
#  820: 'solution',
#  821: 'arrived',
#  822: 'evacuation',
#  823: 'version',
#  824: 'amara',
#  825: 'erzerum',
#  826: 'lies',
#  827: 'massacres',
#  828: 'three',
#  829: 'conception',
#  830: 'elsewhere',
#  831: 'religious',
#  832: 'ul',
#  833: 'attempts',
#  834: 'peaceful',
#  835: 'wrong',
#  836: 'aim',
#  837: 'allies',
#  838: 'huge',
#  839: 'authority',
#  840: 'struggle',
#  841: 'firmly',
#  842: 'arms',
#  843: 'sure',
#  844: 'live',
#  845: 'along',
#  846: 'sacrifice',
#  847: 'territorial',
#  848: 'blow',
#  849: 'witness',
#  850: 'american',
#  851: 'seemed',
#  852: 'else',
#  853: 'command',
#  854: 'capable',
#  855: 'simple',
#  856: 'throw',
#  857: 'easily',
#  858: 'society',
#  859: 'famous',
#  860: 'appeared',
#  861: 'soldier',
#  862: 'line',
#  863: 'happened',
#  864: 'intelligent',
#  865: 'except',
#  866: 'seeing',
#  867: 'balkan',
#  868: 'repeated',
#  869: 'etc',
#  870: 'friendly',
#  871: 'satisfaction',
#  872: 'confined',
#  873: 'southern',
#  874: 'unfortunate',
#  875: 'eminent',
#  876: 'hundred',
#  877: 'russians',
#  878: 'sovereign',
#  879: 'sufferings',
#  880: 'benefit',
#  881: 'principle',
#  882: 'qualities',
#  883: 'act',
#  884: 'shortly',
#  885: 'station',
#  886: 'tax',
#  887: 'business',
#  888: 'broken',
#  889: 'why',
#  890: 'hope',
#  891: 'sufficient',
#  892: 'ambassador',
#  893: 'cowardice',
#  894: 'formed',
#  895: 'bring',
#  896: 'name',
#  897: 'nationalistic',
#  898: 'yussuf',
#  899: 'izzedin',
#  900: 'anxiety',
#  901: 'field',
#  902: 'supplies',
#  903: 'home',
#  904: 'parliament',
#  905: 'sadly',
#  906: 'expense',
#  907: 'marked',
#  908: 'protect',
#  909: 'ago',
#  910: 'mohammedans',
#  911: 'nelken',
#  912: 'section',
#  913: 'accept',
#  914: 'christian',
#  915: 'limited',
#  916: 'fee',
#  917: 'located',
#  918: 'printed',
#  919: 'america',
#  920: 'publish',
#  921: 'hopes',
#  922: 'instincts',
#  923: 'inward',
#  924: 'impossible',
#  925: 'atrocities',
#  926: 'favour',
#  927: 'stay',
#  928: 'contrary',
#  929: 'speaking',
#  930: 'silent',
#  931: 'march',
#  932: 'murder',
#  933: 'prisoner',
#  934: 'loyalty',
#  935: 'communiqués',
#  936: 'worth',
#  937: 'civil',
#  938: 'djemiet',
#  939: 'battle',
#  940: 'adventurers',
#  941: 'morality',
#  942: 'abolition',
#  943: 'founding',
#  944: 'colonisation',
#  945: 'forcible',
#  946: 'mohadjirs',
#  947: 'nucleus',
#  948: 'principles',
#  949: 'alliance',
#  950: 'greed',
#  951: 'murderous',
#  952: 'prevention',
#  953: 'slight',
#  954: 'showed',
#  955: 'rulers',
#  956: 'prevented',
#  957: 'according',
#  958: 'stand',
#  959: 'answer',
#  960: 'lucrative',
#  961: 'slightest',
#  962: 'problem',
#  963: 'relations',
#  964: 'experience',
#  965: 'worthy',
#  966: 'citizens',
#  967: 'slowly',
#  968: 'returned',
#  969: 'imperial',
#  970: 'removal',
#  971: 'dealt',
#  972: 'extraordinary',
#  973: 'harmless',
#  974: 'behind',
#  975: 'beautiful',
#  976: 'sphere',
#  977: 'dead',
#  978: 'attack',
#  979: 'guns',
#  980: 'resistance',
#  981: 'reason',
#  982: 'fighting',
#  983: 'gradually',
#  984: 'break',
#  985: 'cross',
#  986: 'employees',
#  987: 'support',
#  988: 'lot',
#  989: 'deported',
#  990: 'mesopotamia',
#  991: 'discovered',
#  992: 'arranged',
#  993: 'particular',
#  994: 'intercourse',
#  995: 'obtaining',
#  996: 'usually',
#  997: 'definite',
#  998: 'evening',
#  999: 'permitted',
#  1000: 'want',
#  ...}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('project', 2261),
#              ('gutenberg', 2261),
#              ("'s", 4943),
#              ('two', 1070),
#              ('war', 6193),
#              ('years', 682),
#              ('in', 35285),
#              ('constantinople', 2946),
#              ('by', 8875),
#              ('harry', 88),
#              ('stuermer', 115),
#              ('\n\n', 11894),
#              ('this', 9243),
#              ('ebook', 274),
#              ('is', 9141),
#              ('for', 13146),
#              ('the', 113477),
#              ('use', 798),
#              ('of', 74717),
#              ('anyone', 670),
#              ('anywhere', 73),
#              ('united', 440),
#              ('states', 701),
#              ('and', 46968),
#              ('most', 3588),
#              ('other', 1950),
#              ('parts', 364),
#              ('world', 1222),
#              ('at', 7982),
#              ('no', 3276),
#              ('cost', 208),
#              ('with', 12844),
#              ('almost', 208),
#              ('restrictions', 78),
#              ('whatsoever', 156),
#              (' ', 52),
#              ('you', 2340),
#              ('may', 1508),
#              ('copy', 338),
#              ('it', 8892),
#              ('give', 832),
#              ('away', 442),
#              ('or', 5434),
#              ('re', 104),
#              ('under', 1898),
#              ('terms', 598),
#              ('license', 390),
#              ('included', 78),
#              ('online', 156),
#              ('www.gutenberg.org', 130),
#              ('if', 2496),
#              ('are', 3484),
#              ('not', 8242),
#              ('located', 182),
#              ("'ll", 78),
#              ('have', 8710),
#              ('to', 39066),
#              ('check', 130),
#              ('laws', 312),
#              ('country', 1326),
#              ('where', 1326),
#              ('before', 1482),
#              ('using', 208),
#              ('\n\n\n\n', 26),
#              ('title', 130),
#              ('\n       ', 26),
#              ('sketches', 130),
#              ('german', 8086),
#              ('young', 2132),
#              ('turkish', 8190),
#              ('ethics', 286),
#              ('politics', 1118),
#              ('author', 234),
#              ('translator', 26),
#              ('e.', 52),
#              ('allen', 52),
#              ('release', 52),
#              ('date', 130),
#              ('november', 52),
#              ('6', 52),
#              ('2019', 26),
#              ('60638', 26),
#              ('language', 364),
#              ('english', 1248),
#              ('character', 598),
#              ('set', 806),
#              ('encoding', 26),
#              ('iso-8859', 26),
#              ('1', 130),
#              ('start', 156),
#              ('\n\n\n\n\n', 416),
#              ('produced', 208),
#              ('graeme', 52),
#              ('mackreth', 52),
#              ('distributed', 208),
#              ('proofreading', 52),
#              ('team', 52),
#              ('http://www.pgdp.net', 52),
#              ('file', 104),
#              ('was', 12246),
#              ('from', 8658),
#              ('images', 52),
#              ('generously', 52),
#              ('made', 1794),
#              ('available', 364),
#              ('internet', 52),
#              ('archive', 385),
#              ('\n\n\n\n\n\n\n\n\n\n\n ', 26),
#              ('\n ', 312),
#              ('\n\n\n\n\n ', 52),
#              ('\n\n ', 52),
#              ('\n\n\n ', 130),
#              ('dr', 26),
#              ('late', 208),
#              ('correspondent', 286),
#              ('kölnische', 234),
#              ('zeitung', 260),
#              ('1915', 468),
#              ('16', 52),
#              ('translated', 52),
#              ('illustration', 78),
#              ('new', 1055),
#              ('york', 26),
#              ('george', 52),
#              ('h.', 78),
#              ('doran', 52),
#              ('company', 208),
#              ('copyright', 546),
#              ('1917', 104),
#              ('printed', 182),
#              ('america', 182),
#              ('declaration', 130),
#              ('\n\n\n', 390),
#              ('undersigned', 26),
#              ('hereby', 52),
#              ('declares', 26),
#              ('on', 9776),
#              ('his', 7124),
#              ('sworn', 26),
#              ('word', 572),
#              ('honour', 260),
#              ('that', 16874),
#              ('writing', 130),
#              ('volume', 52),
#              ('he', 6864),
#              ('has', 3796),
#              ('been', 4394),
#              ('way', 1768),
#              ('inspired', 78),
#              ('outside', 156),
#              ('influence', 442),
#              ('never', 1430),
#              ('had', 8684),
#              ('any', 4316),
#              ('dealings', 156),
#              ('material', 416),
#              ('otherwise', 234),
#              ('either', 546),
#              ('during', 520),
#              ('government', 2626),
#              ('organisation', 260),
#              ('propaganda', 702),
#              ('personality', 26),
#              ('hostile', 78),
#              ('germany', 3536),
#              ('turkey', 6604),
#              ('even', 4264),
#              ('a', 25870),
#              ('neutral', 520),
#              ('conscience', 234),
#              ('alone', 286),
#              ('urged', 52),
#              ('him', 1872),
#              ('write', 234),
#              ('publish', 182),
#              ('impressions', 234),
#              ('hopes', 182),
#              ('so', 4706),
#              ('doing', 208),
#              ('perform', 52),
#              ('service', 494),
#              ('towards', 1066),
#              ('cause', 728),
#              ('truth', 416),
#              ('civilisation', 936),
#              ('moreover', 26),
#              ('can', 2288),
#              ('formal', 234),
#              ('assurance', 78),
#              ('expressly', 52),
#              ('avoided', 26),
#              ('making', 364),
#              ('acquaintance', 78),
#              ('person', 156),
#              ('resident', 78),
#              ('switzerland', 338),
#              ('until', 338),
#              ('manuscript', 52),
#              ('should', 1248),
#              ('sent', 364),
#              ('press', 416),
#              ('furthermore', 26),
#              ('actuated', 26),
#              ('personal', 1014),
#              ('motives', 26),
#              ('thus', 286),
#              ('giving', 156),
#              ('public', 780),
#              ('expression', 208),
#              ('experiences', 52),
#              ('opinions', 520),
#              ('grievance', 26),
#              ('moral', 442),
#              ('against', 2886),
#              ('dr.', 156),
#              ('geneva', 26),
#              ('june', 78),
#              ('1917_.', 26),
#              ('preface', 52),
#              ('while', 1144),
#              ('work', 1924),
#              ('waiting', 156),
#              ('frontier', 234),
#              ('final', 494),
#              ('permission', 234),
#              ('authorities', 650),
#              ('enter', 78),
#              ('committed', 312),
#              ('her', 2548),
#              ('second', 416),
#              ('great', 1950),
#              ('crime', 338),
#              ('first', 1326),
#              ('having', 468),
#              ('completely', 364),
#              ('missed', 26),
#              ('its', 2028),
#              ('mark', 104),
#              ('she', 1456),
#              ('begun', 130),
#              ('realise', 78),
#              ('beaten', 78),
#              ('conflict', 104),
#              ('which', 5018),
#              ('wantonly', 52),
#              ('provoked', 26),
#              ('characteristic', 208),
#              ('over', 1534),
#              ('confidence', 208),
#              ('power', 598),
#              ('own', 2002),
#              ('militarism', 286),
#              ('disdainful', 78),
#              ('undervaluation', 26),
#              ('morale', 78),
#              ('general', 910),
#              ('capacities', 78),
#              ('enemies', 286),
#              ('renunciation', 26),
#              ('last', 1118),
#              ('remnants', 104),
#              ('humanity', 286),
#              ('methods', 598),
#              ('now', 1690),
#              ('dying', 26),
#              ('effort', 130),
#              ('help', 485),
#              ('already', 1378),
#              ('lost', 442),
#              ('ruthless', 234),
#              ('extension', 78),
#              ('policy', 910),
#              ('piracy', 52),
#              ('sea', 546),
#              ('gratification', 26),
#              ('all', 6604),
#              ('brutal', 416),
#              ('instincts', 182),
#              ('complete', 624),
#              ('violation', 26),
#              ('rights', 234),
#              ('countries', 390),
#              ('therefore', 442),
#              ('more', 3796),
#              ('inward', 182),
#              ('conviction', 208),
#              ('urgent', 52),
#              ('persuasion', 104),
#              ('makes', 130),
#              ('rare', 130),
#              ('opportunity', 754),
#              ('offered', 234),
#              ('residence', 52),
#              ('range', 78),
#              ('himself', 1040),
#              ('boldly', 26),
#              ('side', 884),
#              ('show', 312),
#              ('there', 2756),
#              ('still', 1586),
#              ('germans', 676),
#              ('who', 5538),
#              ('find', 702),
#              ('impossible', 182),
#              ('condone', 78),
#              ('tacitly', 26),
#              ('transgression', 26),
#              ('political', 2340),
#              ('stupidity', 104),
#              ('their', 7306),
#              ('an', 4420),
#              ('allied', 78),
#              ('sole', 52),
#              ('purpose', 156),
#              ('publication', 104),
#              ('regardless', 52),
#              ('consequences', 234),
#              ('holds', 52),
#              ('be', 6968),
#              ('duty', 130),
#              ('privilege', 26),
#              ('just', 884),
#              ('because', 676),
#              ('make', 936),
#              ('frank', 104),
#              ('statement', 26),
#              ('point', 884),
#              ('view', 806),
#              ('human', 312),
#              ('what', 2262),
#              ('become', 520),
#              ('convictions', 52),
#              ('observations', 52),
#              ('course', 1118),
#              ('six', 130),
#              ('months', 390),
#              ('actual', 234),
#              ('warfare', 52),
#              ('practically', 676),
#              ('subsequent', 52),
#              ('journalistic', 78),
#              ('activity', 494),
#              ('spent', 78),
#              ('time', 2418),
#              ('spring', 130),
#              ('christmas', 52),
#              ('1916', 1196),
#              ('will', 4628),
#              ('only', 3068),
#              ('deal', 234),
#              ('knows', 338),
#              ('observation', 78),
#              ('following', 260),
#              ('essays', 26),
#              ('nature', 208),
#              ('merely', 234),
#              ('claim', 52),
#              ('whatever', 364),
#              ('completeness', 26),
#              ('regard', 468),
#              ('purely', 858),
#              ('confine', 104),
#              ('few', 936),
#              ('indications', 130),
#              ('kind', 728),
#              ('but', 5590),
#              ('forget', 104),
#              ('rôle', 208),
#              ('played', 130),
#              ('as', 11700),
#              ('ally', 260),
#              ('present', 910),
#              ('nor', 234),
#              ('ignore', 26),
#              ('responsibility', 104),
#              ('atrocities', 182),
#              ('them', 2574),
#              ('publishes', 26),
#              ('perfectly', 312),
#              ('clear', 494),
#              ('secure', 104),
#              ('representative', 338),
#              ('paper', 1144),
#              ('once', 962),
#              ('wrote', 312),
#              ('single', 468),
#              ('favour', 182),
#              ('criminal', 286),
#              ('stay', 182),
#              ('than', 2132),
#              ('twenty', 156),
#              ('concealed', 130),
#              ('true', 1014),
#              ('soon', 546),
#              ('definitely', 130),
#              ('up', 2262),
#              ('mind', 260),
#              ('these', 3224),
#              ('were', 5642),
#              ('contrary', 182),
#              ('rather', 650),
#              ('dangerously', 26),
#              ('candid', 26),
#              ('speaking', 182),
#              ('wanted', 208),
#              ('listen', 52),
#              ('--', 11128),
#              ('much', 1950),
#              ('miracle', 26),
#              ('ever', 1300),
#              ('reached', 312),
#              ('after', 2366),
#              ('position', 728),
#              ('appeal', 104),
#              ('testimony', 52),
#              ('dozens', 130),
#              ('people', 2678),
#              ('high', 728),
#              ('standing', 130),
#              ('walks', 78),
#              ('life', 1196),
#              ('both', 442),
#              ('thought', 728),
#              ('action', 104),
#              ('deep', 286),
#              ('cleft', 52),
#              ('always', 832),
#              ('divided', 78),
#              ('colleagues', 234),
#              ('ardently', 78),
#              ('longed', 52),
#              ('moment', 650),
#              ('when', 2652),
#              ('might', 1092),
#              ('freely', 234),
#              ('without', 1612),
#              ('fear', 286),
#              ('do', 1794),
#              ('bit', 130),
#              ('enlightenment', 52),
#              ('civilised', 624),
#              ('lines', 208),
#              ('written', 390),
#              ('sincerity', 26),
#              ('submitted', 52),
#              ('tribunal', 26),
#              ('opinion', 702),
#              ('free', 598),
#              ('burden', 52),
#              ('silent', 182),
#              ('reproach', 52),
#              ('heaped', 26),
#              ('mutilated', 52),
#              ('outraged', 104),
#              ('languishing', 26),
#              ('being', 1690),
#              ('among', 936),
#              ('thousands', 806),
#              ('desired', 156),
#              ('\n\n       ', 26),
#              ('      ', 104),
#              ('several', 234),
#              ('passed', 312),
#              ('since', 364),
#              ('original', 156),
#              ('text', 78),
#              ('french', 1040),
#              ('editions', 130),
#              ('little', 832),
#              ('book', 312),
#              ('baghdad', 312),
#              ('taken', 546),
#              ('british', 546),
#              ('troops', 546),
#              ('chapter', 624),
#              ('completed', 52),
#              ('then', 1872),
#              ('military', 2080),
#              ('operations', 156),
#              ('entente', 1352),
#              ('number', 468),
#              ('important', 598),
#              ('events', 390),
#              ('occurred', 156),
#              ('such', 1846),
#              ('russian', 1248),
#              ('revolution', 104),
#              ('entry', 520),
#              ('into', 2002),
#              ('further', 572),
#              ('developments', 52),
#              ('yet', 598),
#              ('direct', 208),
#              ('effect', 286),
#              ('solution', 208),
#              ('problems', 78),
#              ('surrounding', 52),
#              ('defeated', 52),
#              ('ottoman', 962),
#              ('empire', 806),
#              ('preferred', 52),
#              ('maintain', 104),
#              ('early', 260),
#              ('march', 182),
#              ('year', 260),
#              ('changes', 156),
#              ('conclusions', 52),
#              ('arrived', 208),
#              ('result', 572),
#              ('fresh', 52),
#              ('carried', 416),
#              ('contents', 26),
#              ('\n\n\n  ', 260),
#              ('i', 10426),
#              ('\n\n                                                                       ',
#               26),
#              ('page', 78),
#              ('\n\n  ', 572),
#              ('outbreak', 234),
#              ('politicians', 312),
#              ('\n  ', 4784),
#              ('weltpolitiker_)--german', 52),
#              ('mentality', 78),
#              ('place', 962),
#              ('sun', 130),
#              ('"--', 572),
#              ('england', 702),
#              ('belgium', 156),
#              ('alsace', 78),
#              ('lorraine', 78),
#              ('prussian', 156),
#              ('arrogance', 130),
#              ('militaristic', 78),
#              ('journalism', 78),
#              ('                                    ', 52),
#              ('17', 26),
#              ('ii', 52),
#              ('pro', 702),
#              ('considerations', 104),
#              ('dilemma', 78),
#              ('gallipoli', 624),
#              ('control', 338),
#              ('                                                               ',
#               26),
#              ('35', 26),
#              ('iii', 52),
#              ('armenian', 1690),
#              ('persecutions', 546),
#              ('system', 1144),
#              ('talaat', 1248),
#              ('enver', 1950),
#              ('denunciation', 156),
#              ('cowardly', 156),
#              ('conscienceless', 52),
#              ('accomplice', 52),
#              ('                                             ', 26),
#              ('42', 26),
#              ('iv', 52),
#              ('tide', 52),
#              ('offensive', 442),
#              ('liberation', 78),
#              ('caucasus', 416),
#              ('dardanelles', 858),
#              ('campaign', 286),
#              ('fate', 338),
#              ('twice', 104),
#              ('hangs', 52),
#              ('balance', 78),
#              ('nervous', 156),
#              ('tension', 104),
#              ('international', 364),
#              ('pera', 1014),
#              ('bulgaria', 520),
#              ('attitude', 546),
#              ('rancour', 52),
#              ('former', 442),
#              ('enemy', 468),
#              ('illusions', 286),
#              ('separate', 260),
#              ('peace', 806),
#              ('russia', 1560),
#              ('king', 234),
#              ('ferdinand', 78),
#              ('serving', 104),
#              ('lack', 780),
#              ('munitions', 156),
#              ('mysterious', 52),
#              ('death', 650),
#              ('murder', 182),
#              ('?--', 260),
#              ('evacuation', 208),
#              ('version', 208),
#              ('victory', 650),
#              ('unreleased', 52),
#              ('kut', 234),
#              ('el', 286),
#              ('amara', 208),
#              ('holy', 780),
#              ('prisoner', 182),
#              ('repute', 104),
#              ('loyalty', 182),
#              ('anglo', 130),
#              ('indian', 130),
#              ('officers', 624),
#              ('communiqués', 182),
#              ('worth', 182),
#              ('fall', 546),
#              ('erzerum', 208),
#              ('official', 1378),
#              ('lies', 208),
#              ('treatment', 286),
#              ('prisoners', 442),
#              ('speculation', 52),
#              ('subjects', 416),
#              ('stagnation', 78),
#              ('lassitude', 52),
#              ('summer', 520),
#              ('-the', 52),
#              ('greeks', 494),
#              ('dread', 52),
#              ('greek', 780),
#              ('massacres', 208),
#              ('rumania', 312),
#              ('terrible', 832),
#              ('disappointment', 156),
#              ('three', 208),
#              ('phases', 78),
#              ('75', 26),
#              ('v', 78),
#              ('economic', 624),
#              ('situation', 364),
#              ('exaggerated', 156),
#              ('hunger', 156),
#              ('suffering', 156),
#              ('civil', 182),
#              ('population', 858),
#              ('requisitioning', 234),
#              ('semi', 338),
#              ('monopolists', 52),
#              ('profiteering', 78),
#              ('part', 1430),
#              ('clique', 312),
#              ('frivolity', 78),
#              ('cynicism', 104),
#              ('djemiet', 182),
#              ('delegates', 52),
#              ('zentraleinkaufsgesellschaft', 78),
#              ('central', 572),
#              ('purchases', 78),
#              ('commission)--a', 52),
#              ('hard', 286),
#              ('battle', 182),
#              ('between', 936),
#              ('intrigue', 130),
#              ('reform', 546),
#              ('coinage', 130),
#              ('money', 884),
#              ('depreciation', 104),
#              ('hoarding', 52),
#              ('bullion', 78),
#              ('rouble', 52),
#              ('best', 598),
#              ('investment', 52),
#              ('                                                  ', 26),
#              ('107', 26),
#              ('vi', 52),
#              ('unsuccessful', 234),
#              ('government--"the', 52),
#              ('chimera', 52),
#              ('farce', 104),
#              ('underhand', 104),
#              ('embassy', 1248),
#              ('dupe', 78),
#              ('adventurers', 182),
#              ('morality', 182),
#              ('representatives', 234),
#              ('trusty', 104),
#              ('servant', 130),
#              ('fine', 338),
#              ('distinctions', 78),
#              ('conception', 208),
#              ('individuals', 156),
#              ('                                                ', 26),
#              ('126', 26),
#              ('vii', 52),
#              ('nationalism', 104),
#              ('one', 5148),
#              ('sided', 52),
#              ('abolition', 182),
#              ('capitulations', 338),
#              ('--anti', 26),
#              ('foreign', 624),
#              ('efforts', 754),
#              ('emancipation', 234),
#              ('languages', 52),
#              ('simplicity', 78),
#              ('turkification', 442),
#              ('commercial', 1040),
#              ('unmistakable', 104),
#              ('intellectual', 676),
#              ('improvement', 156),
#              ('trade', 598),
#              ('customs', 104),
#              ('tariff', 78),
#              ('national', 572),
#              ('production', 130),
#              ('founding', 182),
#              ('businesses', 156),
#              ('supplanted', 78),
#              ('starvation', 234),
#              ('full', 832),
#              ('european', 1404),
#              ('colonisation', 182),
#              ('forcible', 182),
#              ('anatolia--"the', 52),
#              ('properties', 78),
#              ('dispatched', 104),
#              ('elsewhere', 208),
#              ('mohadjirs', 182),
#              ('discovery', 130),
#              ('anatolia', 1222),
#              ('nucleus', 182),
#              ('finds', 156),
#              ('herself', 234),
#              ('anatolian', 390),
#              ('dirt', 130),
#              ('decay', 104),
#              ('greater', 572),
#              ('cleavage', 52),
#              ('concentration', 156),
#              ('                    ', 26),
#              ('151', 26),
#              ('viii', 52),
#              ('religion', 130),
#              ('race', 1170),
#              ('islam', 754),
#              ('abdul', 494),
#              ('hamid', 468),
#              ('turks', 3380),
#              ('turanism', 390),
#              ('pan', 1092),
#              ('islamism', 312),
#              ('principles', 182),
#              ('quadruple', 52),
#              ('alliance', 182),
#              ('greed', 182),
#              ('fanaticism', 416),
#              ('religious', 208),
#              ('traditions', 104),
#              ('modern', 806),
#              ('reforms', 390),
#              ('law', 624),
#              ('sheikh', 130),
#              ('ul', 208),
#              ('nationalization', 26),
#              ('patriarchates', 78),
#              ('failure', 312),
#              ('alienation', 78),
#              ('arabs', 416),
#              ('djemal', 858),
#              ('pasha', 1274),
#              ('hangman', 234),
#              ('syria', 572),
#              ('attempts', 208),
#              ('suez', 130),
#              ('canal', 156),
#              ('murderous', 182),
#              ('nears', 52),
#              ('completion', 52),
#              ('arabian', 780),
#              ('syrian', 156),
#              ('separatist', 156),
#              ('movement', 338),
#              ('defection', 156),
#              ('emir', 104),
#              ('mecca', 130),
#              ('catastrophe', 156),
#              ('                           ', 26),
#              ('176', 26),
#              ('ix', 52),
#              ('anti', 468),
#              ('feelings', 468),
#              ('pessimism', 104),
#              ('about', 2472),
#              ('how', 1564),
#              ('would', 4628),
#              ('acted', 104),
#              ('prevention', 182),
#              ('agreement', 702),
#              ('peaceful', 208),
#              ('scorned', 52),
#              ('alleged', 52),
#              ('intentions', 104),
#              ('example', 546),
#              ('greece', 442),
#              ('salonika', 78),
#              ('stakes', 104),
#              ('wrong', 208),
#              ('card', 130),
#              ('results', 286),
#              ('                                ', 26),
#              ('209', 26),
#              ('x', 52),
#              ('outlook', 104),
#              ('future', 312),
#              ('trusting', 104),
#              ('sentence', 234),
#              ('social', 988),
#              ('necessity', 364),
#              ('deliverance', 104),
#              ('forecasts', 52),
#              ('element', 494),
#              ('territory', 520),
#              ('guarantees', 104),
#              ('benefits', 104),
#              ('too', 1534),
#              ('farewell', 52),
#              ('interests', 650),
#              ('victorious', 286),
#              ('treaty', 130),
#              ('paradise', 104),
#              ('earth', 156),
#              ('impulse', 26),
#              ('armenia', 520),
#              ('western', 390),
#              ('old', 884),
#              ('centre', 104),
#              ('arabia', 130),
#              ('reconciliation', 78),
#              ('                                                           ',
#               26),
#              ('258', 26),
#              ('appendix', 52),
#              ('                                                             ',
#               26),
#              ('283', 26),
#              ('like', 1300),
#              ('myself', 442),
#              ('foot', 260),
#              ('soil', 104),
#              ('sojourn', 26),
#              ('lands', 390),
#              ('particularly', 338),
#              ('colonies', 234),
#              ('mobilising', 26),
#              ('must', 1300),
#              ('surely', 390),
#              ('filled', 130),
#              ('certain', 572),
#              ('feeling', 416),
#              ('melancholy', 26),
#              ('slight', 182),
#              ('uneasiness', 26),
#              ('state', 884),
#              ('fellow', 104),
#              ('countrymen', 52),
#              ('showed', 182),
#              ('itself', 156),
#              ('dramatic', 286),
#              ('days', 546),
#              ('august', 156),
#              ('conversations', 130),
#              ('street', 104),
#              ('cafés', 26),
#              ('restaurants', 26),
#              ('articles', 364),
#              ('appearing', 130),
#              ('we', 2574),
#              ('learnt', 104),
#              ('think', 442),
#              ('soundly', 26),
#              ('bismarck', 26),
#              ('heritage', 26),
#              ('although', 806),
#              ('forth', 286),
#              ('popular', 52),
#              ('form', 442),
#              ('thoughts', 78),
#              ('recollections', 26),
#              ('opposing', 26),
#              ('prudence', 78),
#              ('utilise', 52),
#              ('unending', 26),
#              ('source', 78),
#              ('descended', 26),
#              ('our', 1400),
#              ('rulers', 182),
#              ('sort', 104),
#              ('living', 260),
#              ('unbounded', 156),
#              ('naïveté', 52),
#              ('incredible', 104),
#              ('judgment', 156),
#              ('understanding', 156),
#              ('peoples', 312),
#              ('raison', 26),
#              ("d'être", 26),
#              ('vital', 130),
#              ('standpoint', 260),
#              ('prevented', 182),
#              ('us', 780),
#              ('trying', 104),
#              ('carry', 234),
#              ('grand', 286),
#              ('weltpolitik', 104),
#              ('average', 78),
#              ('everyday', 52),
#              ('really', 910),
#              ('understood', 52),
#              ('latter', 234),
#              ('colonial', 624),
#              ('according', 182),
#              ('ideas', 494),
#              ('aim', 208),
#              ('snatch', 52),
#              ('liberty', 156),
#              ('entailed', 78),
#              ('mighty', 78),
#              ('sacrifices', 26),
#              ('behalf', 52),
#              ('allies', 208),
#              ('trod', 26),
#              ('belgian', 130),
#              ('neutrality', 104),
#              ('underfoot', 26),
#              ('stand', 182),
#              ('look', 442),
#              ('debates', 26),
#              ('universal', 104),
#              ('every', 1040),
#              ('highest', 338),
#              ('circles', 598),
#              ('ready', 104),
#              ('wager', 52),
#              ('sooner', 26),
#              ('acceptance', 52),
#              ('conscription', 26),
#              ('coming', 104),
#              ('down', 572),
#              ('recent', 104),
#              ('latest', 52),
#              ('huge', 208),
#              ('loan', 52),
#              ('provided', 234),
#              ('fit', 104),
#              ('proper', 260),
#              ('answer', 182),
#              ('frightfulness', 78),
#              ('let', 520),
#              ('me', 2496),
#              ('here', 598),
#              ('say', 702),
#              ('subject', 468),
#              ('perhaps', 858),
#              ('allowed', 312),
#              ('speak', 312),
#              ('amount', 130),
#              ('authority', 208),
#              ('extended', 130),
#              ('travel', 78),
#              ('farthest', 78),
#              ('corners', 78),
#              ('africa', 260),
#              ('intimate', 130),
#              ('knowledge', 468),
#              ('well', 1872),
#              ('less', 468),
#              ('older', 26),
#              ('colonists', 26),
#              ('also', 572),
#              ('struggle', 208),
#              ('widespread', 78),
#              ('intensive', 78),
#              ('lucrative', 182),
#              ('employment', 52),
#              ('energies', 52),
#              ('capabilities', 52),
#              ('highly', 286),
#              ('developed', 78),
#              ('land', 780),
#              ('justified', 130),
#              ('risk', 104),
#              ('dubbed', 26),
#              ('absolutely', 546),
#              ('lacking', 286),
#              ('patriotism', 156),
#              ('out', 2470),
#              ('resources', 104),
#              ('disposal', 130),
#              ('tropical', 78),
#              ('sub', 26),
#              ('exploited', 52),
#              ('they', 5616),
#              ('amply', 26),
#              ('sufficed', 52),
#              ('needs', 338),
#              ('colonising', 26),
#              ('though', 234),
#              ('possibly', 130),
#              ('aspirations', 78),
#              ('secondly', 104),
#              ('very', 2704),
#              ('liberal', 78),
#              ('did', 1378),
#              ...])

# %%
vocabulary_size = len(tokenizer.word_counts)
vocabulary_size
# Out:
# 6443

# %%
type(sequences)
# Out:
# list

# %%
import numpy as np

# %%
sequences = np.array(sequences)

# %%
sequences
# Out:
# array([[  81,   82,   41, ...,  426,  270,    3],
#        [  82,   41,  165, ...,  270,    3,   53],
#        [  41,  165,   33, ...,    3,   53,   91],
#        ...,
#        [ 184,  481,    4, ..., 6443,    4, 3519],
#        [ 481,    4,    1, ...,    4, 3519,   72],
#        [   4,    1,   81, ..., 3519,   72,  168]])

# %%
from keras.utils import to_categorical

# %%
X = sequences[:,:-1]

# %%
y = sequences[:,-1]

# %%
sequences[:,-1]
# Out:
# array([   3,   53,   91, ..., 3519,   72,  168])

# %%
y = to_categorical(y, num_classes=vocabulary_size+1)

# %%
seq_len = X.shape[1]

# %%
X.shape
# Out:
# (57440, 25)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding

# %%
def create_model(vocabulary_size,seq_len):
    
    model = Sequential()
    model.add(Embedding(vocabulary_size,seq_len,input_length=seq_len))
    model.add(LSTM(50,return_sequences=True))
    model.add(LSTM(50))
    model.add(Dense(50,activation='relu'))
    
    model.add(Dense(vocabulary_size,activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimiser='adam', metrics=['accuracy'])
    
    model.summary()
    
    return model

# %%
model = create_model(vocabulary_size+1, seq_len)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 25, 25)            161100
# _________________________________________________________________
# lstm (LSTM)                  (None, 25, 50)            15200
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 50)                2550
# _________________________________________________________________
# dense_1 (Dense)              (None, 6444)              328644
# =================================================================
# Total params: 527,694
# Trainable params: 527,694
# Non-trainable params: 0
# _________________________________________________________________

# %%
from pickle import dump,load

# %%
model.fit(X,y,batch_size=128,epochs=2,verbose=1)
# Out:
# Train on 57440 samples
# Epoch 1/2
# 57440/57440 [==============================] - 120s 2ms/sample - loss: 6.7180 - accuracy: 0.0747
# Epoch 2/2
# 57440/57440 [==============================] - 103s 2ms/sample - loss: 6.4179 - accuracy: 0.0882

# %%
model.save('novel_brain.h5')

# %%
dump(tokenizer,open('simpletokenizer','wb'))

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
def generate_text(model,tokenizer,seq_len,seed_text,num_gen_words):
    
    output_text = []
    
    input_text = seed_text
    
    for i in range(num_gen_words):
        encoded_text = tokenizer.texts_to_sequences([input_text])[0]
        pad_encoded = pad_sequences([encoded_text], maxlen=seq_len,truncating='pre')
        pred_word_ind = model.predict_classes(pad_encoded,verbose=0)[0]
        pred_word = tokenizer.index_word[pred_word_ind]
        input_text += ' '+pred_word
        output_text.append(pred_word)
        
    return ' '.join(output_text)

# %%
#text_sequences[0]

# %%
#text_sequences[1]

# %%
import random
random.seed(101)
random_pick = random.randint(0,len(text_sequences))

# %%
random_seed_text = text_sequences[random_pick]
random_seed_text
# Out:
# ['man',
#  'with',
#  'a',
#  'murderer',
#  "'s",
#  'face',
#  'and',
#  'a',
#  'murderer',
#  "'s",
#  'instinct',
#  'to',
#  'credit',
#  'him',
#  'with',
#  'honest',
#  'sympathies',
#  'for',
#  'france',
#  '\n\n',
#  'djemal',
#  "'s",
#  'work',
#  'is',
#  'nearing',
#  'fruition']

# %%
seed_text = ' '.join(random_seed_text)

# %%
seed_text
# Out:
# "man with a murderer 's face and a murderer 's instinct to credit him with honest sympathies for france \n\n djemal 's work is nearing fruition"

# %%
generate_text(model,tokenizer,seq_len,seed_text=seed_text,num_gen_words=25)
# Out:
# 'the german of of the german of of the german of of the german of of the german of of the german of of the'

# %%
from keras.models import load_model

# %%
model = load_model ('epochBIG.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-182-114e94f07acf> in <module>
# ----> 1 model = load_model ('epochBIG.h5')
#
# /anaconda3/envs/keras_python3_6/lib/python3.6/site-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     415     model = None
#     416     opened_new_file = not isinstance(filepath, h5py.Group)
# --> 417     f = h5dict(filepath, 'r')
#     418     try:
#     419         model = _deserialize_model(f, custom_objects, compile)
#
# /anaconda3/envs/keras_python3_6/lib/python3.6/site-packages/keras/utils/io_utils.py in __init__(self, path, mode)
#     184             self._is_file = False
#     185         elif isinstance(path, str):
# --> 186             self.data = h5py.File(path, mode=mode)
#     187             self._is_file = True
#     188         elif isinstance(path, dict):
#
# /anaconda3/envs/keras_python3_6/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     392                 fid = make_fid(name, mode, userblock_size,
#     393                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 394                                swmr=swmr)
#     395
#     396             if swmr_support:
#
# /anaconda3/envs/keras_python3_6/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     168         if swmr and swmr_support:
#     169             flags |= h5f.ACC_SWMR_READ
# --> 170         fid = h5f.open(name, flags, fapl=fapl)
#     171     elif mode == 'r+':
#     172         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'epochBIG.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
tokenizer = load(open('epochBIG','rb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-183-97b060ec76bc> in <module>
# ----> 1 tokenizer = load(open('epochBIG','rb'))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'epochBIG'

# %%
generate_text(model,tokenizer,seq_len,seed_text=seed_text,num_gen_words=25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-94ec6604db47> in <module>
# ----> 1 generate_text(model,tokenizer,seq_len,seed_text=seed_text,num_gen_words=25)
#
# <ipython-input-81-41ee9d145bfe> in generate_text(model, tokenizer, seq_len, seed_text, num_gen_words)
#       7     for i in range(num_gen_words):
#       8         encoded_text = tokenizer.texts_to_sequences([input_text])[0]
# ----> 9         pad_encoded = pad_sequences([encoded_text], maxlen=seq_len,truncation='pre')
#      10         pre_word_ind = model.predit_classes(pad_encoded,verbose=0)[0]
#      11         input_text += ' '+pred_word
#
# NameError: name 'pad_sequences' is not defined
